# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/BERT-LS
# Out:
# /content/drive/MyDrive/BERT-LS

# %%
# !pip install -r requirements.txt

# %%
BERT_DIR = "/content/drive/MyDrive/BERT-LS"
RESULT_DIR = f"{BERT_DIR}/results"

# !mkdir -p {RESULT_DIR}  # Make sure the results folder exists

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# !python LSBert1.py \
  --do_eval \
  --do_lower_case \
  --num_selections 10 \
  --eval_dir {BERT_DIR}/datasets/BenchLS.txt \
  --bert_model bert-large-uncased-whole-word-masking \
  --max_seq_length 250 \
  --word_embeddings /content/drive/MyDrive/BERT-LS/embeddings/crawl-300d-2M.vec \
  --word_frequency {BERT_DIR}/frequency_merge_wiki_child.txt \
  --output_SR_file {RESULT_DIR}/aaa
# Out:
# 2025-04-14 22:31:29.386398: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744669889.434501   26382 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744669889.450240   26382 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-14 22:31:29.576684: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !git add requirements.txt
# !git commit -m "Add requirements.txt for project dependencies"
# !git push
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@57239cbb0436.(none)')
# Everything up-to-date

# %%
# !git config --global user.email "avand.lakmazaheri@gmail.com"
# !git config --global user.name "lakmazah"

# %%
# !echo "embeddings/*.vec" >> .gitignore

# %%
# %ls
# Out:
# BERT_LS.png                     plural.py
# complex_word.py                 PPDB/
# conlleval.py                    pytorch_pretrained_bert/
# datasets/                       README.md
# evaluator.py                    read_xls.py
# Example1.png                    recursive_LSBert2.py
# experiment.py                   recursive_simplification.txt
# frequency_merge_wiki_child.txt  requirements.txt
# helper_functions.py             run_LSBert1.sh
# hubconf.py                      run_LSBert2.sh
# labeler.py                      run_LSBert2_TS.sh
# LSBert1.py                      simplification.py
# LSBert2.py                      SUBTLEX_frequency.xlsx
# ls_test.ipynb                   verb/
